# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
np.random.seed(777)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# Data: https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# ## 7.3 Feature engineering and preprocess data for input into the model

# %% [markdown]
# ### Import the data

# %%
credit_df = pd.read_csv("./creditcard.csv")

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
credit_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
credit_df.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# Scale the features so as to mitigate the biasness towards one feature

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X = credit_df.iloc[:,:-1]
Y = credit_df.iloc[:,-1]
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2,random_state=100, stratify=Y)

# %%
Y_train.value_counts()
# Out:
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64

# %%
Y_test.value_counts()
# Out:
# Class
# 0    56864
# 1       98
# Name: count, dtype: int64

# %%
mmscale = MinMaxScaler()
mmscale.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = mmscale.transform(X_train)

# %%
X_test = mmscale.transform(X_test)

# %% [markdown]
# ### 7.4 Create the model and the optimizer

# %%
def get_model():
    model = Sequential()
    model.add(Dense(30,input_shape=(30,), activation='relu'))
    model.add(Dense(15, activation='relu'))
    model.add(Dense(5, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    print(model.summary())
    return model

# %%
from tensorflow.keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# get the model
model = get_model()

# compile the model
model.compile(optimizer='RMSProp', loss='binary_crossentropy', metrics=['acc',f1_m,precision_m, recall_m])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                930
#
#  dense_1 (Dense)             (None, 15)                465
#
#  dense_2 (Dense)             (None, 5)                 80
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 1481 (5.79 KB)
# Trainable params: 1481 (5.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# ## 7.5 - Train the model

# %%
# fit the model
history = model.fit(X_train, Y_train, validation_split=0.1, epochs=50, verbose=1,batch_size=1000)

# evaluate the model
loss, accuracy, f1_score, precision, recall = model.evaluate(X_test, Y_test, verbose=0)
# Out:
# Epoch 1/50
# 206/206 [==============================] - 15s 12ms/step - loss: 0.0811 - acc: 0.9983 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_loss: 0.0115 - val_acc: 0.9983 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0114 - acc: 0.9983 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_loss: 0.0109 - val_acc: 0.9983 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 3/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0105 - acc: 0.9983 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_loss: 0.0097 - val_acc: 0.9983 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 4/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0089 - acc: 0.9983 - f1_m: 0.0065 - precision_m: 0.0097 - recall_m: 0.0049 - val_loss: 0.0077 - val_acc: 0.9985 - val_f1_m: 0.1435 - val_precision_m: 0.2174 - val_recall_m: 0.1159
# Epoch 5/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0068 - acc: 0.9986 - f1_m: 0.1874 - precision_m: 0.2743 - recall_m: 0.1581 - val_loss: 0.0056 - val_acc: 0.9988 - val_f1_m: 0.2739 - val_precision_m: 0.3913 - val_recall_m: 0.2333
# Epoch 6/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0050 - acc: 0.9989 - f1_m: 0.3779 - precision_m: 0.4624 - recall_m: 0.3460 - val_loss: 0.0044 - val_acc: 0.9989 - val_f1_m: 0.3739 - val_precision_m: 0.5217 - val_recall_m: 0.3203
# Epoch 7/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0040 - acc: 0.9991 - f1_m: 0.4887 - precision_m: 0.5840 - recall_m: 0.4461 - val_loss: 0.0055 - val_acc: 0.9994 - val_f1_m: 0.5775 - val_precision_m: 0.6232 - val_recall_m: 0.5478
# Epoch 8/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0037 - acc: 0.9993 - f1_m: 0.5695 - precision_m: 0.6284 - recall_m: 0.5531 - val_loss: 0.0036 - val_acc: 0.9993 - val_f1_m: 0.5413 - val_precision_m: 0.6232 - val_recall_m: 0.4971
# Epoch 9/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0035 - acc: 0.9993 - f1_m: 0.5782 - precision_m: 0.6323 - recall_m: 0.5667 - val_loss: 0.0034 - val_acc: 0.9993 - val_f1_m: 0.5543 - val_precision_m: 0.6232 - val_recall_m: 0.5116
# Epoch 10/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0034 - acc: 0.9993 - f1_m: 0.6264 - precision_m: 0.6865 - recall_m: 0.6208 - val_loss: 0.0033 - val_acc: 0.9993 - val_f1_m: 0.5543 - val_precision_m: 0.6232 - val_recall_m: 0.5116
# Epoch 11/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0034 - acc: 0.9993 - f1_m: 0.6287 - precision_m: 0.6837 - recall_m: 0.6153 - val_loss: 0.0033 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 12/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0033 - acc: 0.9993 - f1_m: 0.6076 - precision_m: 0.6498 - recall_m: 0.6075 - val_loss: 0.0033 - val_acc: 0.9994 - val_f1_m: 0.5630 - val_precision_m: 0.6232 - val_recall_m: 0.5261
# Epoch 13/50
# 206/206 [==============================] - 2s 8ms/step - loss: 0.0033 - acc: 0.9994 - f1_m: 0.6626 - precision_m: 0.7037 - recall_m: 0.6633 - val_loss: 0.0033 - val_acc: 0.9994 - val_f1_m: 0.5691 - val_precision_m: 0.6232 - val_recall_m: 0.5348
# Epoch 14/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0033 - acc: 0.9994 - f1_m: 0.6288 - precision_m: 0.6786 - recall_m: 0.6187 - val_loss: 0.0033 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 15/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0033 - acc: 0.9994 - f1_m: 0.6193 - precision_m: 0.6617 - recall_m: 0.6126 - val_loss: 0.0033 - val_acc: 0.9995 - val_f1_m: 0.5919 - val_precision_m: 0.6268 - val_recall_m: 0.5710
# Epoch 16/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0033 - acc: 0.9994 - f1_m: 0.6487 - precision_m: 0.6987 - recall_m: 0.6377 - val_loss: 0.0033 - val_acc: 0.9995 - val_f1_m: 0.5919 - val_precision_m: 0.6268 - val_recall_m: 0.5710
# Epoch 17/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0032 - acc: 0.9994 - f1_m: 0.6401 - precision_m: 0.6749 - recall_m: 0.6414 - val_loss: 0.0033 - val_acc: 0.9993 - val_f1_m: 0.5741 - val_precision_m: 0.5725 - val_recall_m: 0.5855
# Epoch 18/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0032 - acc: 0.9994 - f1_m: 0.6455 - precision_m: 0.6876 - recall_m: 0.6447 - val_loss: 0.0055 - val_acc: 0.9991 - val_f1_m: 0.5658 - val_precision_m: 0.5616 - val_recall_m: 0.5855
# Epoch 19/50
# 206/206 [==============================] - 2s 8ms/step - loss: 0.0032 - acc: 0.9994 - f1_m: 0.6342 - precision_m: 0.6722 - recall_m: 0.6396 - val_loss: 0.0033 - val_acc: 0.9995 - val_f1_m: 0.5919 - val_precision_m: 0.6268 - val_recall_m: 0.5710
# Epoch 20/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0032 - acc: 0.9994 - f1_m: 0.6356 - precision_m: 0.6670 - recall_m: 0.6361 - val_loss: 0.0035 - val_acc: 0.9994 - val_f1_m: 0.5604 - val_precision_m: 0.6232 - val_recall_m: 0.5203
# Epoch 21/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0032 - acc: 0.9994 - f1_m: 0.6588 - precision_m: 0.6946 - recall_m: 0.6583 - val_loss: 0.0033 - val_acc: 0.9993 - val_f1_m: 0.5741 - val_precision_m: 0.5725 - val_recall_m: 0.5855
# Epoch 22/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0032 - acc: 0.9994 - f1_m: 0.6480 - precision_m: 0.6773 - recall_m: 0.6558 - val_loss: 0.0057 - val_acc: 0.9991 - val_f1_m: 0.5658 - val_precision_m: 0.5616 - val_recall_m: 0.5855
# Epoch 23/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0032 - acc: 0.9994 - f1_m: 0.6698 - precision_m: 0.7133 - recall_m: 0.6643 - val_loss: 0.0034 - val_acc: 0.9994 - val_f1_m: 0.5691 - val_precision_m: 0.6232 - val_recall_m: 0.5348
# Epoch 24/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0032 - acc: 0.9994 - f1_m: 0.6283 - precision_m: 0.6637 - recall_m: 0.6264 - val_loss: 0.0032 - val_acc: 0.9994 - val_f1_m: 0.5741 - val_precision_m: 0.5725 - val_recall_m: 0.5855
# Epoch 25/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6467 - precision_m: 0.6818 - recall_m: 0.6470 - val_loss: 0.0034 - val_acc: 0.9994 - val_f1_m: 0.5691 - val_precision_m: 0.6232 - val_recall_m: 0.5348
# Epoch 26/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6565 - precision_m: 0.6997 - recall_m: 0.6530 - val_loss: 0.0032 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 27/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6393 - precision_m: 0.6742 - recall_m: 0.6358 - val_loss: 0.0035 - val_acc: 0.9994 - val_f1_m: 0.5691 - val_precision_m: 0.6232 - val_recall_m: 0.5348
# Epoch 28/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6599 - precision_m: 0.7100 - recall_m: 0.6519 - val_loss: 0.0033 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 29/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6426 - precision_m: 0.6735 - recall_m: 0.6535 - val_loss: 0.0032 - val_acc: 0.9995 - val_f1_m: 0.5948 - val_precision_m: 0.6123 - val_recall_m: 0.5855
# Epoch 30/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6320 - precision_m: 0.6703 - recall_m: 0.6350 - val_loss: 0.0033 - val_acc: 0.9993 - val_f1_m: 0.5694 - val_precision_m: 0.5659 - val_recall_m: 0.5855
# Epoch 31/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6483 - precision_m: 0.6769 - recall_m: 0.6506 - val_loss: 0.0032 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 32/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6881 - precision_m: 0.7229 - recall_m: 0.6955 - val_loss: 0.0032 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 33/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6404 - precision_m: 0.6806 - recall_m: 0.6362 - val_loss: 0.0032 - val_acc: 0.9995 - val_f1_m: 0.5948 - val_precision_m: 0.6123 - val_recall_m: 0.5855
# Epoch 34/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6667 - precision_m: 0.7058 - recall_m: 0.6671 - val_loss: 0.0033 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 35/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6482 - precision_m: 0.6675 - recall_m: 0.6621 - val_loss: 0.0041 - val_acc: 0.9991 - val_f1_m: 0.5658 - val_precision_m: 0.5616 - val_recall_m: 0.5855
# Epoch 36/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6119 - precision_m: 0.6434 - recall_m: 0.6189 - val_loss: 0.0032 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 37/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6464 - precision_m: 0.6727 - recall_m: 0.6562 - val_loss: 0.0032 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 38/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6579 - precision_m: 0.6995 - recall_m: 0.6611 - val_loss: 0.0032 - val_acc: 0.9995 - val_f1_m: 0.5948 - val_precision_m: 0.6123 - val_recall_m: 0.5855
# Epoch 39/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6443 - precision_m: 0.6756 - recall_m: 0.6497 - val_loss: 0.0032 - val_acc: 0.9995 - val_f1_m: 0.5948 - val_precision_m: 0.6123 - val_recall_m: 0.5855
# Epoch 40/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6501 - precision_m: 0.6834 - recall_m: 0.6478 - val_loss: 0.0032 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 41/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6426 - precision_m: 0.6789 - recall_m: 0.6450 - val_loss: 0.0055 - val_acc: 0.9991 - val_f1_m: 0.5658 - val_precision_m: 0.5616 - val_recall_m: 0.5855
# Epoch 42/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6256 - precision_m: 0.6625 - recall_m: 0.6226 - val_loss: 0.0032 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 43/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6794 - precision_m: 0.7197 - recall_m: 0.6689 - val_loss: 0.0032 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 44/50
# 206/206 [==============================] - 2s 8ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6130 - precision_m: 0.6442 - recall_m: 0.6196 - val_loss: 0.0032 - val_acc: 0.9995 - val_f1_m: 0.5948 - val_precision_m: 0.6123 - val_recall_m: 0.5855
# Epoch 45/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.0030 - acc: 0.9994 - f1_m: 0.6495 - precision_m: 0.6811 - recall_m: 0.6555 - val_loss: 0.0035 - val_acc: 0.9994 - val_f1_m: 0.5691 - val_precision_m: 0.6232 - val_recall_m: 0.5348
# Epoch 46/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0030 - acc: 0.9994 - f1_m: 0.6559 - precision_m: 0.6923 - recall_m: 0.6559 - val_loss: 0.0032 - val_acc: 0.9996 - val_f1_m: 0.6006 - val_precision_m: 0.6268 - val_recall_m: 0.5855
# Epoch 47/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6204 - precision_m: 0.6541 - recall_m: 0.6199 - val_loss: 0.0032 - val_acc: 0.9995 - val_f1_m: 0.5948 - val_precision_m: 0.6123 - val_recall_m: 0.5855
# Epoch 48/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.0030 - acc: 0.9994 - f1_m: 0.6689 - precision_m: 0.7100 - recall_m: 0.6658 - val_loss: 0.0032 - val_acc: 0.9995 - val_f1_m: 0.5948 - val_precision_m: 0.6123 - val_recall_m: 0.5855
# Epoch 49/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6945 - precision_m: 0.7261 - recall_m: 0.7060 - val_loss: 0.0031 - val_acc: 0.9995 - val_f1_m: 0.5948 - val_precision_m: 0.6123 - val_recall_m: 0.5855
# Epoch 50/50
# 206/206 [==============================] - 2s 7ms/step - loss: 0.0031 - acc: 0.9994 - f1_m: 0.6799 - precision_m: 0.7095 - recall_m: 0.6937 - val_loss: 0.0033 - val_acc: 0.9993 - val_f1_m: 0.5781 - val_precision_m: 0.5804 - val_recall_m: 0.5855

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
  print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
  print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
  print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
  print('Total Fraudulent Transactions: ', np.sum(cm[1]))

# %%
train_predictions_baseline = model.predict(X_train, batch_size=1000)
test_predictions_baseline = model.predict(X_test, batch_size=1000)
# Out:
# 228/228 [==============================] - 2s 4ms/step
# 57/57 [==============================] - 0s 4ms/step

# %%
import sklearn
from sklearn.metrics import confusion_matrix, roc_auc_score, classification_report, roc_curve

# %%
plot_cm(Y_test, test_predictions_baseline)
# Out:
# Legitimate Transactions Detected (True Negatives):  56843
# Legitimate Transactions Incorrectly Detected (False Positives):  21
# Fraudulent Transactions Missed (False Negatives):  23
# Fraudulent Transactions Detected (True Positives):  75
# Total Fraudulent Transactions:  98

# %%
print(classification_report(Y_test,test_predictions_baseline>0.5))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.78      0.77      0.77        98
#
#     accuracy                           1.00     56962
#    macro avg       0.89      0.88      0.89     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
print(roc_auc_score(Y_test,test_predictions_baseline>0.5))
# Out:
# 0.8824684101271347

# %% [markdown]
# ## 7.6 - Handling Class Imbalance

# %% [markdown]
# #### Increase class weight of positive instances

# %%
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
neg, pos = np.bincount(credit_df['Class'])
total = neg + pos
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 0.50
# Weight for class 1: 289.44

# %%
weighted_model = get_model()

# compile the model
weighted_model.compile(optimizer='RMSProp', loss='binary_crossentropy', metrics=['acc',f1_m,precision_m, recall_m])

# fit the model
history = weighted_model.fit(X_train, Y_train, validation_split=0.1, epochs=50, verbose=1,batch_size=1000, class_weight=class_weight)

# evaluate the model
loss, accuracy, f1_score, precision, recall = weighted_model.evaluate(X_test, Y_test, verbose=0)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 30)                930
#
#  dense_5 (Dense)             (None, 15)                465
#
#  dense_6 (Dense)             (None, 5)                 80
#
#  dense_7 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 1481 (5.79 KB)
# Trainable params: 1481 (5.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 206/206 [==============================] - 6s 11ms/step - loss: 0.6088 - acc: 0.9986 - f1_m: 0.2110 - precision_m: 0.2537 - recall_m: 0.1989 - val_loss: 0.6630 - val_acc: 0.6556 - val_f1_m: 0.0094 - val_precision_m: 0.0048 - val_recall_m: 0.7246
# Epoch 2/50
# 206/206 [==============================] - 2s 8ms/step - loss: 0.5108 - acc: 0.9954 - f1_m: 0.4736 - precision_m: 0.5063 - recall_m: 0.5314 - val_loss: 0.1865 - val_acc: 0.9989 - val_f1_m: 0.5531 - val_precision_m: 0.5725 - val_recall_m: 0.5478
# Epoch 3/50
# 206/206 [==============================] - 2s 7ms/step - loss: 0.3657 - acc: 0.9904 - f1_m: 0.4523 - precision_m: 0.4129 - recall_m: 0.6917 - val_loss: 0.0861 - val_acc: 0.9988 - val_f1_m: 0.5302 - val_precision_m: 0.5217 - val_recall_m: 0.5710
# Epoch 4/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.2610 - acc: 0.9780 - f1_m: 0.3154 - precision_m: 0.2570 - recall_m: 0.7084 - val_loss: 0.0748 - val_acc: 0.9978 - val_f1_m: 0.4752 - val_precision_m: 0.4225 - val_recall_m: 0.5855
# Epoch 5/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.2191 - acc: 0.9684 - f1_m: 0.2547 - precision_m: 0.1911 - recall_m: 0.7189 - val_loss: 0.0863 - val_acc: 0.9943 - val_f1_m: 0.3061 - val_precision_m: 0.2188 - val_recall_m: 0.5855
# Epoch 6/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.2058 - acc: 0.9666 - f1_m: 0.2129 - precision_m: 0.1482 - recall_m: 0.7418 - val_loss: 0.0442 - val_acc: 0.9969 - val_f1_m: 0.4298 - val_precision_m: 0.3671 - val_recall_m: 0.5855
# Epoch 7/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1995 - acc: 0.9675 - f1_m: 0.2239 - precision_m: 0.1577 - recall_m: 0.7299 - val_loss: 0.2005 - val_acc: 0.9523 - val_f1_m: 0.0577 - val_precision_m: 0.0306 - val_recall_m: 0.6435
# Epoch 8/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1937 - acc: 0.9628 - f1_m: 0.1931 - precision_m: 0.1274 - recall_m: 0.7580 - val_loss: 0.1871 - val_acc: 0.9537 - val_f1_m: 0.0593 - val_precision_m: 0.0315 - val_recall_m: 0.6435
# Epoch 9/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1989 - acc: 0.9600 - f1_m: 0.1754 - precision_m: 0.1119 - recall_m: 0.7494 - val_loss: 0.0953 - val_acc: 0.9839 - val_f1_m: 0.1447 - val_precision_m: 0.0848 - val_recall_m: 0.6000
# Epoch 10/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1922 - acc: 0.9581 - f1_m: 0.1835 - precision_m: 0.1227 - recall_m: 0.7252 - val_loss: 0.0660 - val_acc: 0.9908 - val_f1_m: 0.2272 - val_precision_m: 0.1468 - val_recall_m: 0.6000
# Epoch 11/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1931 - acc: 0.9590 - f1_m: 0.1741 - precision_m: 0.1134 - recall_m: 0.7506 - val_loss: 0.0418 - val_acc: 0.9952 - val_f1_m: 0.3336 - val_precision_m: 0.2444 - val_recall_m: 0.5855
# Epoch 12/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1910 - acc: 0.9638 - f1_m: 0.1896 - precision_m: 0.1286 - recall_m: 0.7617 - val_loss: 0.1389 - val_acc: 0.9659 - val_f1_m: 0.0783 - val_precision_m: 0.0424 - val_recall_m: 0.6435
# Epoch 13/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1883 - acc: 0.9596 - f1_m: 0.1616 - precision_m: 0.1047 - recall_m: 0.7231 - val_loss: 0.2085 - val_acc: 0.9381 - val_f1_m: 0.0461 - val_precision_m: 0.0241 - val_recall_m: 0.6522
# Epoch 14/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1827 - acc: 0.9600 - f1_m: 0.2103 - precision_m: 0.1431 - recall_m: 0.7650 - val_loss: 0.1291 - val_acc: 0.9666 - val_f1_m: 0.0798 - val_precision_m: 0.0433 - val_recall_m: 0.6435
# Epoch 15/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1945 - acc: 0.9634 - f1_m: 0.1567 - precision_m: 0.1004 - recall_m: 0.7383 - val_loss: 0.0523 - val_acc: 0.9925 - val_f1_m: 0.2568 - val_precision_m: 0.1728 - val_recall_m: 0.6000
# Epoch 16/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1919 - acc: 0.9638 - f1_m: 0.1566 - precision_m: 0.0973 - recall_m: 0.7617 - val_loss: 0.0777 - val_acc: 0.9859 - val_f1_m: 0.1603 - val_precision_m: 0.0958 - val_recall_m: 0.6000
# Epoch 17/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1879 - acc: 0.9598 - f1_m: 0.1724 - precision_m: 0.1118 - recall_m: 0.7640 - val_loss: 0.0524 - val_acc: 0.9924 - val_f1_m: 0.2489 - val_precision_m: 0.1643 - val_recall_m: 0.6000
# Epoch 18/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1916 - acc: 0.9639 - f1_m: 0.1596 - precision_m: 0.1011 - recall_m: 0.7206 - val_loss: 0.0360 - val_acc: 0.9959 - val_f1_m: 0.3790 - val_precision_m: 0.2982 - val_recall_m: 0.5855
# Epoch 19/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.1890 - acc: 0.9664 - f1_m: 0.1826 - precision_m: 0.1175 - recall_m: 0.7338 - val_loss: 0.1234 - val_acc: 0.9727 - val_f1_m: 0.0959 - val_precision_m: 0.0530 - val_recall_m: 0.6435
# Epoch 20/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1842 - acc: 0.9653 - f1_m: 0.1697 - precision_m: 0.1078 - recall_m: 0.7525 - val_loss: 0.0857 - val_acc: 0.9845 - val_f1_m: 0.1496 - val_precision_m: 0.0873 - val_recall_m: 0.6435
# Epoch 21/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1817 - acc: 0.9625 - f1_m: 0.1593 - precision_m: 0.0987 - recall_m: 0.7587 - val_loss: 0.0447 - val_acc: 0.9946 - val_f1_m: 0.3151 - val_precision_m: 0.2248 - val_recall_m: 0.6000
# Epoch 22/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1903 - acc: 0.9677 - f1_m: 0.1714 - precision_m: 0.1100 - recall_m: 0.7380 - val_loss: 0.0655 - val_acc: 0.9895 - val_f1_m: 0.2001 - val_precision_m: 0.1265 - val_recall_m: 0.6000
# Epoch 23/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1854 - acc: 0.9642 - f1_m: 0.1669 - precision_m: 0.1093 - recall_m: 0.7505 - val_loss: 0.0588 - val_acc: 0.9914 - val_f1_m: 0.2285 - val_precision_m: 0.1474 - val_recall_m: 0.6000
# Epoch 24/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1862 - acc: 0.9653 - f1_m: 0.1637 - precision_m: 0.1038 - recall_m: 0.7367 - val_loss: 0.1979 - val_acc: 0.9422 - val_f1_m: 0.0494 - val_precision_m: 0.0260 - val_recall_m: 0.6522
# Epoch 25/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1796 - acc: 0.9676 - f1_m: 0.1639 - precision_m: 0.1027 - recall_m: 0.7444 - val_loss: 0.2479 - val_acc: 0.9339 - val_f1_m: 0.0436 - val_precision_m: 0.0228 - val_recall_m: 0.6522
# Epoch 26/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1788 - acc: 0.9601 - f1_m: 0.1669 - precision_m: 0.1084 - recall_m: 0.7132 - val_loss: 0.0340 - val_acc: 0.9958 - val_f1_m: 0.3733 - val_precision_m: 0.2909 - val_recall_m: 0.6000
# Epoch 27/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1871 - acc: 0.9669 - f1_m: 0.1631 - precision_m: 0.1037 - recall_m: 0.7254 - val_loss: 0.0865 - val_acc: 0.9838 - val_f1_m: 0.1483 - val_precision_m: 0.0866 - val_recall_m: 0.6435
# Epoch 28/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1792 - acc: 0.9659 - f1_m: 0.1828 - precision_m: 0.1185 - recall_m: 0.7525 - val_loss: 0.1223 - val_acc: 0.9705 - val_f1_m: 0.0877 - val_precision_m: 0.0480 - val_recall_m: 0.6435
# Epoch 29/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1872 - acc: 0.9647 - f1_m: 0.1564 - precision_m: 0.0979 - recall_m: 0.7472 - val_loss: 0.0864 - val_acc: 0.9831 - val_f1_m: 0.1434 - val_precision_m: 0.0832 - val_recall_m: 0.6435
# Epoch 30/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1790 - acc: 0.9699 - f1_m: 0.1761 - precision_m: 0.1145 - recall_m: 0.7739 - val_loss: 0.0419 - val_acc: 0.9951 - val_f1_m: 0.3266 - val_precision_m: 0.2370 - val_recall_m: 0.6000
# Epoch 31/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1779 - acc: 0.9709 - f1_m: 0.2091 - precision_m: 0.1409 - recall_m: 0.7500 - val_loss: 0.0775 - val_acc: 0.9876 - val_f1_m: 0.1795 - val_precision_m: 0.1081 - val_recall_m: 0.6435
# Epoch 32/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1736 - acc: 0.9669 - f1_m: 0.1795 - precision_m: 0.1205 - recall_m: 0.7217 - val_loss: 0.0464 - val_acc: 0.9956 - val_f1_m: 0.3475 - val_precision_m: 0.2555 - val_recall_m: 0.6000
# Epoch 33/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1770 - acc: 0.9668 - f1_m: 0.2138 - precision_m: 0.1554 - recall_m: 0.6909 - val_loss: 0.0727 - val_acc: 0.9904 - val_f1_m: 0.2161 - val_precision_m: 0.1364 - val_recall_m: 0.6435
# Epoch 34/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1829 - acc: 0.9692 - f1_m: 0.1893 - precision_m: 0.1291 - recall_m: 0.6972 - val_loss: 0.0919 - val_acc: 0.9862 - val_f1_m: 0.1692 - val_precision_m: 0.1015 - val_recall_m: 0.6435
# Epoch 35/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1774 - acc: 0.9686 - f1_m: 0.1995 - precision_m: 0.1402 - recall_m: 0.7721 - val_loss: 0.0676 - val_acc: 0.9907 - val_f1_m: 0.2188 - val_precision_m: 0.1382 - val_recall_m: 0.6435
# Epoch 36/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1761 - acc: 0.9677 - f1_m: 0.1768 - precision_m: 0.1126 - recall_m: 0.7682 - val_loss: 0.0362 - val_acc: 0.9947 - val_f1_m: 0.3239 - val_precision_m: 0.2369 - val_recall_m: 0.6000
# Epoch 37/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1719 - acc: 0.9607 - f1_m: 0.1874 - precision_m: 0.1279 - recall_m: 0.7391 - val_loss: 0.0965 - val_acc: 0.9792 - val_f1_m: 0.1184 - val_precision_m: 0.0670 - val_recall_m: 0.6435
# Epoch 38/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1782 - acc: 0.9684 - f1_m: 0.1802 - precision_m: 0.1175 - recall_m: 0.7358 - val_loss: 0.0955 - val_acc: 0.9837 - val_f1_m: 0.1462 - val_precision_m: 0.0852 - val_recall_m: 0.6435
# Epoch 39/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1687 - acc: 0.9653 - f1_m: 0.1988 - precision_m: 0.1316 - recall_m: 0.7640 - val_loss: 0.0259 - val_acc: 0.9968 - val_f1_m: 0.4226 - val_precision_m: 0.3495 - val_recall_m: 0.6000
# Epoch 40/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1775 - acc: 0.9650 - f1_m: 0.1755 - precision_m: 0.1143 - recall_m: 0.7479 - val_loss: 0.0763 - val_acc: 0.9859 - val_f1_m: 0.1631 - val_precision_m: 0.0972 - val_recall_m: 0.6435
# Epoch 41/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1795 - acc: 0.9691 - f1_m: 0.1728 - precision_m: 0.1191 - recall_m: 0.7135 - val_loss: 0.1674 - val_acc: 0.9515 - val_f1_m: 0.0579 - val_precision_m: 0.0306 - val_recall_m: 0.6522
# Epoch 42/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1643 - acc: 0.9690 - f1_m: 0.2127 - precision_m: 0.1439 - recall_m: 0.7969 - val_loss: 0.0367 - val_acc: 0.9964 - val_f1_m: 0.3908 - val_precision_m: 0.3036 - val_recall_m: 0.6000
# Epoch 43/50
# 206/206 [==============================] - 1s 4ms/step - loss: 0.1698 - acc: 0.9681 - f1_m: 0.2154 - precision_m: 0.1529 - recall_m: 0.7430 - val_loss: 0.0716 - val_acc: 0.9889 - val_f1_m: 0.1944 - val_precision_m: 0.1196 - val_recall_m: 0.6435
# Epoch 44/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1671 - acc: 0.9671 - f1_m: 0.1732 - precision_m: 0.1099 - recall_m: 0.7420 - val_loss: 0.0351 - val_acc: 0.9945 - val_f1_m: 0.3067 - val_precision_m: 0.2178 - val_recall_m: 0.6000
# Epoch 45/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1780 - acc: 0.9648 - f1_m: 0.1487 - precision_m: 0.0905 - recall_m: 0.7345 - val_loss: 0.1232 - val_acc: 0.9711 - val_f1_m: 0.0894 - val_precision_m: 0.0490 - val_recall_m: 0.6435
# Epoch 46/50
# 206/206 [==============================] - 1s 7ms/step - loss: 0.1752 - acc: 0.9697 - f1_m: 0.1743 - precision_m: 0.1129 - recall_m: 0.7569 - val_loss: 0.1491 - val_acc: 0.9633 - val_f1_m: 0.0718 - val_precision_m: 0.0386 - val_recall_m: 0.6435
# Epoch 47/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1720 - acc: 0.9701 - f1_m: 0.1789 - precision_m: 0.1154 - recall_m: 0.7539 - val_loss: 0.0514 - val_acc: 0.9913 - val_f1_m: 0.2309 - val_precision_m: 0.1506 - val_recall_m: 0.6000
# Epoch 48/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1712 - acc: 0.9696 - f1_m: 0.1949 - precision_m: 0.1339 - recall_m: 0.7650 - val_loss: 0.0467 - val_acc: 0.9939 - val_f1_m: 0.2961 - val_precision_m: 0.2083 - val_recall_m: 0.6000
# Epoch 49/50
# 206/206 [==============================] - 1s 5ms/step - loss: 0.1766 - acc: 0.9700 - f1_m: 0.1722 - precision_m: 0.1088 - recall_m: 0.7280 - val_loss: 0.0708 - val_acc: 0.9891 - val_f1_m: 0.1962 - val_precision_m: 0.1228 - val_recall_m: 0.6000
# Epoch 50/50
# 206/206 [==============================] - 1s 6ms/step - loss: 0.1658 - acc: 0.9667 - f1_m: 0.1914 - precision_m: 0.1290 - recall_m: 0.7701 - val_loss: 0.0419 - val_acc: 0.9913 - val_f1_m: 0.2290 - val_precision_m: 0.1494 - val_recall_m: 0.6000

# %% [markdown]
# ## 7.7 - Evaluate the final model and predict fraud using the model

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
def find_optimal_cutoff(target, predicted):
    """ Find the optimal probability cutoff point for a classification model related to event rate
    Parameters
    ----------
    target : Matrix with dependent or target data, where rows are observations

    predicted : Matrix with predicted data, where rows are observations

    Returns
    -------     
    list type, with optimal cutoff value

    """
    fpr, tpr, threshold = roc_curve(target, predicted)
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'threshold' : pd.Series(threshold, index=i)})
    roc_t = roc.iloc[(roc.tf-0).abs().argsort()[:1]]
    # Plot tpr vs 1-fpr
    fig, ax = plt.subplots()
    plt.plot(tpr)
    plt.plot(1-fpr, color = 'red')
    plt.xlabel('1-False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    ax.set_xticklabels([])
    return list(roc_t['threshold'])

# %%
test_predictions_weighted = weighted_model.predict(X_test, batch_size=1000)
# Out:
# 57/57 [==============================] - 1s 3ms/step

# %%
find_optimal_cutoff(Y_test, test_predictions_weighted)
# Out:
# [0.05511446297168732]

# %%
plot_cm(Y_test, test_predictions_weighted, p=0.21)
# Out:
# Legitimate Transactions Detected (True Negatives):  55405
# Legitimate Transactions Incorrectly Detected (False Positives):  1459
# Fraudulent Transactions Missed (False Negatives):  15
# Fraudulent Transactions Detected (True Positives):  83
# Total Fraudulent Transactions:  98

# %%
print(classification_report(Y_test, test_predictions_weighted>0.21))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.05      0.85      0.10        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.91      0.54     56962
# weighted avg       1.00      0.97      0.99     56962

# %%
roc_auc_score(Y_test, test_predictions_weighted>0.21)
# Out:
# 0.9106405329436222
